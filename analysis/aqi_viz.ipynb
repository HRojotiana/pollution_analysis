# %%
import matplotlib.pyplot as plt
import seaborn as sns
from extraction.extract_pollution_data import aqis_datas

# %%
aqis = aqis_datas()
plt.figure(figsize=(10, 6))
sns.histplot(aqis['mean'], kde=True)
plt.title('aqis distribution per location')
plt.xlabel('Mean values')
plt.ylabel('Frequences')
plt.show()
